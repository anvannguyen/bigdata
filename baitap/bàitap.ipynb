# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-2b66debd-7e64-49f2-bf97-4f6962f74e97" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2b66debd-7e64-49f2-bf97-4f6962f74e97">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving senate_county.csv to senate_county.csv

# %%
uploaded
# Out:
# {'senate_county.csv': b"state,county,current_votes,total_votes,percent\nDelaware,Kent County,84929,88000,95\nDelaware,New Castle County,278066,293878,95\nDelaware,Sussex County,126468,125000,95\nGeorgia,Appling County,8187,8341,98\nGeorgia,Atkinson County,3097,3155,98\nGeorgia,Bacon County,4590,4668,100\nGeorgia,Baker County,1531,1552,99\nGeorgia,Baldwin County,18039,18205,99\nGeorgia,Banks County,8704,8786,99\nGeorgia,Barrow County,37611,38000,99\nGeorgia,Bartow County,49952,50375,99\nGeorgia,Ben Hill County,6476,6559,99\nGeorgia,Berrien County,7639,7731,99\nGeorgia,Bibb County,69799,70623,99\nGeorgia,Bleckley County,5642,5704,99\nGeorgia,Brantley County,7602,7731,98\nGeorgia,Brooks County,6966,7077,98\nGeorgia,Bryan County,21161,21338,99\nGeorgia,Bulloch County,29760,30010,99\nGeorgia,Burke County,10556,10680,99\nGeorgia,Butts County,11685,11786,99\nGeorgia,Calhoun County,2171,2193,99\nGeorgia,Camden County,23334,23671,99\nGeorgia,Candler County,4362,4419,99\nGeorgia,Carroll County
# ...

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt 
# %matplotlib inline
import seaborn as sns
import csv
df = pd.read_csv('senate_county.csv',index_col=0, encoding= 'unicode_escape')

# %%
df.head()
# Out:
#                      county  current_votes  total_votes  percent
# state
# Delaware        Kent County          84929        88000       95
# Delaware  New Castle County         278066       293878       95
# Delaware      Sussex County         126468       125000       95
# Georgia      Appling County           8187         8341       98
# Georgia     Atkinson County           3097         3155       98

# %%
sns.lmplot(x='current_votes', y='total_votes', data=df)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import tree
from sklearn.metrics import accuracy_score
# %matplotlib inline
sns.set()

# %%
df_train = pd.read_csv('governors_county.csv')
df_test = pd.read_csv('governors_county_candidate.csv')

# %%
df_train.head()
# Out:
#       state             county  current_votes  total_votes  percent
# 0  Delaware        Kent County          85399        88000       95
# 1  Delaware  New Castle County         278691       293878       95
# 2  Delaware      Sussex County         127168       125000       95
# 3   Indiana       Adams County          14153        14238       99
# 4   Indiana       Allen County         140363       164793       85

# %%
df_test.head()
# Out:
#       state             county        candidate party   votes
# 0  Delaware        Kent County      John Carney   DEM   44343
# 1  Delaware        Kent County  Julianne Murray   REP   39325
# 2  Delaware        Kent County  Kathy DeMatteis   IPD    1115
# 3  Delaware        Kent County    John Machurek   LIB     616
# 4  Delaware  New Castle County      John Carney   DEM  190941

# %%
df_train.describe()
# Out:
#        current_votes   total_votes      percent
# count   1.025000e+03  1.025000e+03  1025.000000
# mean    1.905734e+04  1.970298e+04    93.516098
# std     6.176145e+04  6.389178e+04     9.375208
# min     0.000000e+00  5.000000e+00     0.000000
# 25%     1.078000e+03  1.136000e+03    95.000000
# 50%     3.730000e+03  3.872000e+03    95.000000
# 75%     1.285500e+04  1.326400e+04    95.000000
# max     1.162592e+06  1.148274e+06   100.000000

# %%
sns.countplot(x='county', data=df_test);
